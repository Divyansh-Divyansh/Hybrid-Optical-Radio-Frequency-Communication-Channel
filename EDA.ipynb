# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import concurrent.futures
from sklearn.linear_model import LinearRegression

# %%
# Load the dataset
data = pd.read_csv("RFLFSODataFull.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91379 entries, 0 to 91378
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FSO_Att                91379 non-null  float64
#  1   RFL_Att                91379 non-null  float64
#  2   AbsoluteHumidity       91379 non-null  float64
#  3   AbsoluteHumidityMax    91379 non-null  float64
#  4   AbsoluteHumidityMin    91379 non-null  float64
#  5   Distance               91379 non-null  float64
#  6   Frequency              91379 non-null  int64
#  7   Particulate            91379 non-null  float64
#  8   ParticulateMax         91379 non-null  float64
#  9   ParticulateMin         91379 non-null  float64
#  10  RainIntensity          91379 non-null  float64
#  11  RainIntensityMax       91379 non-null  float64
#  12  RainIntensityMin       91379 non-null  float64
#  13  RelativeHumidity       91379 non-null  float64
#  14  SYNOPCode              91379 non-null  int64
#  15  Temperature            91379 non-null  float64
#  16  TemperatureDifference  91379 non-null  float64
#  17  TemperatureMax         91379 non-null  float64
#  18  TemperatureMin         91379 non-null  float64
#  19  Time                   91379 non-null  int64
#  20  Visibility             91379 non-null  float64
#  21  VisibilityMax          91379 non-null  float64
#  22  VisibilityMin          91379 non-null  float64
#  23  WindDirection          91379 non-null  float64
#  24  WindSpeed              91379 non-null  float64
#  25  WindSpeedMax           91379 non-null  float64
#  26  WindSpeedMin           91379 non-null  float64
# dtypes: float64(24), int64(3)
# memory usage: 18.8 MB

# %%
data.head()
# Out:
#     FSO_Att   RFL_Att  AbsoluteHumidity  AbsoluteHumidityMax  \
# 0  7.913289  6.927868         17.595709            17.615907
# 1  7.451176  4.412096         17.549693            17.572415
# 2  7.072747  6.268740         17.290230            17.644014
# 3  6.949288  4.317853         16.820880            17.066776
# 4  7.361052  6.114514         16.813820            17.953974
#
#    AbsoluteHumidityMin     Distance    Frequency  Particulate  ParticulateMax  \
# 0            17.340148  2115.338398  83500000000          0.0             0.0
# 1            17.299439  2113.999257  73500000000          0.0             0.0
# 2            16.037894  2118.689047  83500000000          0.0             0.0
# 3            15.895622  2114.632339  73500000000          0.0             0.0
# 4            15.227225  2116.786055  83500000000          0.0             0.0
#
#    ParticulateMin  ...  TemperatureMax  TemperatureMin  Time   Visibility  \
# 0             0.0  ...       26.603030       24.680849     9  65884.51846
# 1             0.0  ...       26.377164       24.313108     9  64963.41092
# 2             0.0  ...       27.670822       23.150277    10  54794.28107
# 3             0.0  ...       26.522100       23.174815    10  50205.64159
# 4             0.0  ...       26.305736       24.864100    10  59038.32599
#
#    VisibilityMax  VisibilityMin  WindDirection  WindSpeed  WindSpeedMax  \
# 0   72336.362233   65617.543754      88.755450   3.057066      6.863808
# 1   68753.386153   60379.327485      99.790057   2.727910      6.468903
# 2   54821.773817   50850.155963      65.730085   1.674810      2.826916
# 3   52519.927530   45374.510898      88.127497   0.962068      2.780643
# 4   64418.329138   54461.246506      84.167414   1.881007      4.476298
#
#    WindSpeedMin
# 0      3.007939
# 1      2.537393
# 2      1.640809
# 3      0.886951
# 4      1.874052
#
# [5 rows x 27 columns]

# %%
data.describe()
# Out:
#             FSO_Att       RFL_Att  AbsoluteHumidity  AbsoluteHumidityMax  \
# count  91379.000000  91379.000000      91379.000000         91379.000000
# mean       6.769458     11.619098          9.553919            10.032760
# std        3.903843      3.438873          5.858577             6.162798
# min        0.788363      0.027142          1.141556             1.238270
# 25%        3.473063     10.829331          4.958993             5.205861
# 50%        6.336167     11.856560          6.870737             7.205499
# 75%        8.664984     12.847944         14.049470            14.782679
# max       32.455222     46.893150         24.790883            26.407305
#
#        AbsoluteHumidityMin      Distance     Frequency   Particulate  \
# count         91379.000000  91379.000000  9.137900e+04  91379.000000
# mean              9.076251   3297.930328  7.850005e+10     27.065979
# std               5.575927   1224.305893  5.000027e+09     72.134023
# min               1.049744   2012.000148  7.350000e+10      0.000000
# 25%               4.709511   2019.431812  7.350000e+10      0.000000
# 50%               6.524046   2959.863686  8.350000e+10      0.000000
# 75%              13.379256   4820.890157  8.350000e+10     16.947618
# max              24.268431   4827.999971  8.350000e+10   1621.001906
#
#        ParticulateMax  ParticulateMin  ...  TemperatureMax  TemperatureMin  \
# count    91379.000000    91379.000000  ...    91379.000000    91379.000000
# mean        28.417120       25.717089  ...       13.166020       11.904558
# std         75.761896       68.595239  ...        9.589755        8.694028
# min          0.000000        0.000000  ...       -6.693373       -7.270075
# 25%          0.000000        0.000000  ...        4.905387        4.438425
# 50%          0.000000        0.000000  ...       10.803943        9.774467
# 75%         17.775980       16.038090  ...       22.470382       20.322434
# max       1753.747866     1500.666382  ...       40.771383       36.724191
#
#                Time    Visibility  VisibilityMax  VisibilityMin  \
# count  91379.000000  91379.000000   91379.000000   91379.000000
# mean      11.373193  32986.417484   34636.684647   31331.618978
# std        6.942229  24713.874445   25978.845228   23497.873065
# min        0.000000     10.151990      11.029667       9.484346
# 25%        5.000000  11158.598400   11721.447542   10588.793237
# 50%       11.000000  26378.636210   27686.214032   25047.188462
# 75%       17.000000  53493.821285   56092.212376   50797.690402
# max       23.000000  75004.999150   82503.130084   74999.343414
#
#        WindDirection     WindSpeed  WindSpeedMax  WindSpeedMin
# count   91379.000000  91379.000000  91379.000000  91379.000000
# mean       89.043304      0.739065      1.851020      0.702242
# std        26.415610      0.871314      1.762698      0.828796
# min         0.000000      0.000000      0.000000      0.000000
# 25%        82.976727      0.076749      0.512667      0.072912
# 50%        90.867362      0.437995      1.323101      0.416274
# 75%        98.482652      1.088621      2.681788      1.036574
# max       360.000000      7.799086     16.421115      7.252319
#
# [8 rows x 27 columns]

# %%
data.isna().sum()
# Out:
# FSO_Att                  0
# RFL_Att                  0
# AbsoluteHumidity         0
# AbsoluteHumidityMax      0
# AbsoluteHumidityMin      0
# Distance                 0
# Frequency                0
# Particulate              0
# ParticulateMax           0
# ParticulateMin           0
# RainIntensity            0
# RainIntensityMax         0
# RainIntensityMin         0
# RelativeHumidity         0
# SYNOPCode                0
# Temperature              0
# TemperatureDifference    0
# TemperatureMax           0
# TemperatureMin           0
# Time                     0
# Visibility               0
# VisibilityMax            0
# VisibilityMin            0
# WindDirection            0
# WindSpeed                0
# WindSpeedMax             0
# WindSpeedMin             0
# dtype: int64
